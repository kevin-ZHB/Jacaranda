# %% [markdown]
# ## Jacaranda Python 入门课程 - 第一节：介绍与环境搭建
#                                                     - By 赵圣琪 David
#
# # 课程介绍
# - 该课程为 Jacaranda社团量化部为未入门 Python 基础的社员提供的辅导课程
# - 课程内容介绍
#     - Basic - 编译器的本地建设
#     - Basic - 基础Python语法
#     - Extended - 金融数据的处理工具： Pandas
#     - Basic - 代码编写的逻辑
# - 预期学习成果
#     - Basic - 能够利用Python语言处理基础的数据
#     - Basic - 能够利用Python语言处理复杂的金融数据
#     - Extended - 能够使用Python语言编写独立的交易策略
# - 课程安排
#     - 本课程包括六节课，每节课预估时间在 45mins - 60mins
#     - Python 介绍与环境搭建
#     - Python 变量的定义与输出
#     - Python 数据类型与简单数据结构
#     - Python 逻辑结构
#     - Python 函数的书写
#     - Python 面向对象
# - 对应课程
#     - Uni Melbourne
#         - Bachelor – Comp10001
#         - Master – Comp90059
#     - Uni Sydney
#         - Bachelor - Info1110
#         - Master – Info9001

# %% [markdown]
# # Python语言介绍
# - 可读性强且简单
#     - 语言块简单易懂
#         - list().append(‘Python is so easy ！’)
#             - append 的意思是添加，这个语句的作用是 在list的末尾添加一个 “python is so easy ！” 这句话
#     - 可嵌入
#         - 你可以将Python嵌入到C/C++程序，让你的程序的用户获得"脚本化"的能力。
# - 应用面广
#     - 可以调用很多第三方开源库 基本可以涵盖所有行业的所有需求
#         - 数据处理库： mysql、pandas、Numpy...
#         - 数学处理库： Matplotlib、math...
#         - 爬虫自动化库：selenium、request...
#         - 金融数据库：tushare...
#         - 机器学习库: TensorFlow
# - 商业接口很多
#     - 绝大多数券商都有API接口
#     - 绝大多数加密货币平台也有API接口
#     - 绝大多数金融数据平台也有API接口

# %% [markdown]
# # 本地架构安装
# -   VS Code
#     - https://huaweicloud.csdn.net/63a5665ab878a545459463e1.html?spm=1001.2101.3001.6661.1&utm_medium=distribute.pc_relevant_t0.none-task-blog-2~default~BlogCommendFromBaidu~activity-1-122179913-blog-113793024.pc_relevant_vip_default&depth_1-utm_source=distribute.pc_relevant_t0.none-task-blog-2~default~BlogCommendFromBaidu~activity-1-122179913-blog-113793024.pc_relevant_vip_default&utm_relevant_index=1#1%EF%BC%89%E7%82%B9%E5%87%BB%E8%A7%82%E7%9C%8B%E6%95%99%E7%A8%8B%EF%BC%9B?login=from_csdn
#
#
#
# - 第三方库集成软件 - Anaconda
#   - https://www.anaconda.com/download
#
#
# - 编译器 - PyCharm
#   - https://www.jetbrains.com/pycharm/
#   - https://blog.csdn.net/qq_45158642/article/details/127081741

# %% [markdown]
# # Python的基础语法
# - 基础的输入输出结构 - IPO模型
#     - I ： input
#         - 输入
#     - P ： process
#         - 处理
#     - O ：output
#         - 输出
#     - Example：
#         - 例如需要将一个未排序的数据组合按照升序排序后得到一个正确顺序的数据
#         - I：未排序的数据组合
#         - P：将数据排序
#         - O：排序完成的数据组合

# %%
# 这是Input
Input = [2,1,3,4,0,5]
# 这是Process
Input.sort(reverse=False)
# 这是Output
print(Input)
# Out:
# [0, 1, 2, 3, 4, 5]

# %% [markdown]
# - IPO模型进阶练习 - 四则运算

# %%
num1 = 50#输入第一个数字
num2 = 10#输入第二个数字
def ys(num1,num2):#创建一个自定义运算函数，设置两个形参
    result1 = num1 + num2#加法运算
    result4 = num1 / num2#除法运算
    print(result1)#打印加法运算的结果
    print(result4)#打印除法运算的结果
ys(num1,num2)#调用函数，并传入实参
# Out:
# 60
# 5.0

# %% [markdown]
# 练习1: 完善四则运算法则，增加减法和乘法运算

# %% [markdown]
# - Python语言的书写规范
#     - 缩进
#         - 缩进表示包含关系，一般是四个空格
#         - 缩进不一致会报错
#         - 多行语句 - 用 / 来换行
#         - 一行内的多行语句 - 用 ; 来续写
#     - 转义字符 - \
#         - 有一些特殊功能是由转义符+字符组成的
#         - 换行符\n

# %%
for i in '1':
    print('下一行会换行',end = '\n')
    print('下一行不换行',end = ' ' )
    print('我在上一句的屁股后边')
# Out:
# 下一行会换行
# 下一行不换行 我在上一句的屁股后边

# %% [markdown]
# # Python 小游戏 - Turtle

# %%
import turtle
turtle.getscreen()

# %% [markdown]
# - 如何画一条线

# %%
turtle.shape('turtle')	#海龟图形
turtle.pensize(5)		#设置画笔的粗细
turtle.color('red','green')		#设置画笔的颜色和乌龟的颜色
turtle.forward(100)
turtle.done()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 5
#       3 turtle.color('red','green')		#设置画笔的颜色和乌龟的颜色
#       4 turtle.forward(100)
# ----> 5 turtle.done()
#
# File <string>:8, in mainloop()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/turtle.py:812, in TurtleScreenBase.mainloop(self)
#     799 def mainloop(self):
#     800     """Starts event loop - calling Tkinter's mainloop function.
#     801
#     802     No argument.
#    (...)
#     810
#     811     """
# --> 812     self.cv.tk.mainloop()
#
# KeyboardInterrupt:

# %% [markdown]
# - 一些小工具

# %%
turtle.goto(0,0) # 海龟回到原点
turtle.clear() # 清除海龟绘画痕迹

# %%
turtle.shape('turtle')
turtle.pensize(5)
turtle.color('red','green')
turtle.forward(100)
turtle.right(90)	#设置海龟旋转角度
turtle.forward(100)
turtle.right(90)
turtle.forward(100)
turtle.right(90)
turtle.forward(100)
turtle.done()

# %% [markdown]
# - 练习2:画一个绿色的等腰三角形

# %%
import turtle
t = turtle.Pen()

color = ['red','yellow','blue','black','blue']

for i in range(50):
    t.pencolor(color[i%4])
    t.forward(i)
    t.left(90.1)
turtle.done()

# %%
turtle.Screen().bye()

# %% [markdown]
# # Homework
# - 完成python编译器的本地安装
# - 使用turtle画一个带颜色的圣诞树🎄
